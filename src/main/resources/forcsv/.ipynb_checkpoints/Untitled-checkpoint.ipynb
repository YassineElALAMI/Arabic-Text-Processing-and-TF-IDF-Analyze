# %%
import pandas as pd 

data = pd.read_csv("matrix_tfidf.csv")

data.head(20)
# Out:
#            term  doc1.txt  doc2.txt  doc3.txt  doc4.txt  doc5.txt
# 0         اتساع  0.000000  0.000000  0.000000  0.040358  0.000000
# 1         اثارا  0.000000  0.037475  0.000000  0.000000  0.000000
# 2         اجهزة  0.000000  0.000000  0.041149  0.000000  0.000000
# 3         اخرون  0.000000  0.000000  0.000000  0.040358  0.000000
# 4        اساسيا  0.000000  0.000000  0.000000  0.040358  0.000000
# 5       استثمرت  0.000000  0.000000  0.000000  0.000000  0.037475
# 6    استراتيجية  0.000000  0.037475  0.000000  0.000000  0.000000
# 7         اصبحت  0.000000  0.000000  0.000000  0.000000  0.037475
# 8         اطلاق  0.036818  0.000000  0.000000  0.000000  0.000000
# 9        اعتماد  0.000000  0.037475  0.000000  0.000000  0.000000
# 10         اكبر  0.000000  0.037475  0.000000  0.000000  0.000000
# 11   الاجتماعية  0.000000  0.000000  0.041149  0.000000  0.000000
# 12    الاستثمار  0.029704  0.000000  0.033199  0.000000  0.000000
# ...
