# %%
import pandas as pd

data = pd.read_csv("matrix_tfidf.csv")

data.head(20)
# Out:
#                                                                       term  \
# Word = اتساع      Stemming_results = [{type = STEM      morpheme = اتساع}]
# Word = اثارا      Stemming_results = [{type = STEM       morpheme = اثار}]
# Word = اجهزه      Stemming_results = [{type = STEM       morpheme = اجهز}]
# Word = اخرون      Stemming_results = [{type = STEM        morpheme = اخر}]
# Word = اساسيا     Stemming_results = [{type = STEM      morpheme = اساسي}]
# Word = استثمرت    Stemming_results = [{type = STEM    morpheme = استثمرت}]
# Word = استراتيجيه Stemming_results = [{type = STEM   morpheme = استراتيج}]
# Word = اصبحت      Stemming_results = [{type = STEM      morpheme = اصبحت}]
# Word = اطلاق      Stemming_results = [{type = STEM      morpheme = اطلاق}]
# Word = اعتماد     Stemming_results = [{type = STEM     morpheme = اعتماد}]
# Word = اكبر       Stemming_results = [{type = STEM       morpheme = اكبر}]
# ...
